# %%
import ipywidgets as widgets
from IPython.display import display

# Phase 1: Attention Head Analysis
phase1 = widgets.VBox([
    widgets.Label("🔍 Phase 1: Attention Head Analysis"),
    widgets.Checkbox(value=False, description="Corner heads: CLS/BOS attention"),
    widgets.Checkbox(value=False, description="IOI heads: syntactic disambiguation"),
    widgets.Checkbox(value=False, description="Patch heads: image region focus"),
    widgets.Checkbox(value=False, description="Attention rollout across layers"),
])

# Phase 2: Embedding Extraction
phase2 = widgets.VBox([
    widgets.Label("🧠 Phase 2: Embedding Extraction"),
    widgets.Checkbox(value=False, description="Final-layer embeddings (all modalities)"),
    widgets.Checkbox(value=False, description="Metadata: ID, modality, transformation, label"),
])

# Phase 3: Embedding Diagnostics
phase3 = widgets.VBox([
    widgets.Label("📊 Phase 3: Embedding Diagnostics"),
    widgets.Checkbox(value=False, description="Cosine similarity matrix"),
    widgets.Checkbox(value=False, description="UMAP / t-SNE visualization"),
    widgets.Checkbox(value=False, description="PCA variance analysis"),
    widgets.Checkbox(value=False, description="Embedding trajectory plots"),
    widgets.Checkbox(value=False, description="Cluster analysis (k-means / DBSCAN)"),
])

# Phase 4: Cross-modal Alignment
phase4 = widgets.VBox([
    widgets.Label("🧭 Phase 4: Cross-modal Alignment"),
    widgets.Checkbox(value=False, description="Attention vs embedding correlation"),
    widgets.Checkbox(value=False, description="Custom drift metrics"),
    widgets.Checkbox(value=False, description="Modality fusion diagnostics"),
])

# Combine all phases into a sidebar
sidebar = widgets.VBox([
    widgets.Label("🧭 Semantic Drift Diagnostic Checklist"),
    phase1,
    phase2,
    phase3,
    phase4
])

display(sidebar)
